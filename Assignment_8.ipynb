# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshavardhanrajuthonti/NLP/blob/main/Nlp_assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Example text data
text = """Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her."""

# Tokenization and preparing sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# Create input sequences
input_sequences = []
for i in range(1, len(tokenizer.texts_to_sequences([text])[0])):
    n_gram_sequence = tokenizer.texts_to_sequences([text])[0][:i+1]
    input_sequences.append(n_gram_sequence)

# Pad sequences
max_seq_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))

# Inputs and labels
X = input_sequences[:, :-1]
y = input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# Define Transformer-based model using MultiHeadAttention
def transformer_block(vocab_size, seq_len):
    inputs = tf.keras.layers.Input(shape=(seq_len,))
    embedding = tf.keras.layers.Embedding(vocab_size, 64)(inputs)

    # Multi-Head Attention Layer
    attention_output = tf.keras.layers.MultiHeadAttention(num_heads=2, key_dim=64)(embedding, embedding)
    attention_output = tf.keras.layers.LayerNormalization()(attention_output + embedding)

    # Feed-forward network
    ff_output = tf.keras.layers.Dense(128, activation='relu')(attention_output)
    ff_output = tf.keras.layers.Dense(64)(ff_output)
    ff_output = tf.keras.layers.LayerNormalization()(ff_output + attention_output)

    outputs = tf.keras.layers.GlobalAveragePooling1D()(ff_output)
    outputs = tf.keras.layers.Dense(vocab_size, activation='softmax')(outputs)

    model = tf.keras.models.Model(inputs, outputs)
    return model

# Build model
model = transformer_block(total_words, max_seq_len-1)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the model (20, 60, 70 epochs)
epochs_list = [20, 60, 70]
history = []
for epoch in epochs_list:
    print(f"Training with {epoch} epochs...")
    h = model.fit(X, y, epochs=epoch, verbose=1)
    history.append(h)

# Text generation using seed text
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=1)
        output_word = tokenizer.index_word[predicted_word_index[0]]
        seed_text += " " + output_word
    return seed_text

seed_text = "Once upon a time"
generated_text = generate_text(seed_text, 50, model, max_seq_len)
print("Generated text:", generated_text)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 55)]                 0         []
#
#  embedding (Embedding)       (None, 55, 64)               2624      ['input_1[0][0]']
#
#  multi_head_attention (Mult  (None, 55, 64)               33216     ['embedding[0][0]',
#  iHeadAttention)                                                     'embedding[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 55, 64)               0         ['multi_head_attention[0][0]',
#  Lambda)                                                             'embedding[0][0]']
#
#  layer_normalization (Layer  (None, 55, 64)               128       ['tf.__operators__.add[0][0]']
#  Normalization)
#
#  dense (Dense)               (None, 55, 128)              8320      ['layer_normalization[0][0]']
#
#  dense_1 (Dense)             (None, 55, 64)               8256      ['dense[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 55, 64)               0         ['dense_1[0][0]',
#  OpLambda)                                                           'layer_normalization[0][0]']
#
#  layer_normalization_1 (Lay  (None, 55, 64)               128       ['tf.__operators__.add_1[0][0]
#  erNormalization)                                                   ']
#
#  global_average_pooling1d (  (None, 64)                   0         ['layer_normalization_1[0][0]'
#  GlobalAveragePooling1D)                                            ]
#
#  dense_2 (Dense)             (None, 41)                   2665      ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 55337 (216.16 KB)
# Trainable params: 55337 (216.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Training with 20 epochs...
# Epoch 1/20
# 2/2 [==============================] - 2s 34ms/step - loss: 4.0812 - accuracy: 0.0182
# Epoch 2/20
# 2/2 [==============================] - 0s 28ms/step - loss: 3.7270 - accuracy: 0.0545
# Epoch 3/20
# 2/2 [==============================] - 0s 26ms/step - loss: 3.5714 - accuracy: 0.1455
# Epoch 4/20
# 2/2 [==============================] - 0s 24ms/step - loss: 3.5227 - accuracy: 0.1273
# Epoch 5/20
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4729 - accuracy: 0.1091
# Epoch 6/20
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4412 - accuracy: 0.1091
# Epoch 7/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4029 - accuracy: 0.1273
# Epoch 8/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.3646 - accuracy: 0.1273
# Epoch 9/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.3491 - accuracy: 0.1273
# Epoch 10/20
# 2/2 [==============================] - 0s 23ms/step - loss: 3.3164 - accuracy: 0.1273
# Epoch 11/20
# 2/2 [==============================] - 0s 23ms/step - loss: 3.2877 - accuracy: 0.1273
# Epoch 12/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.2679 - accuracy: 0.1273
# Epoch 13/20
# 2/2 [==============================] - 0s 23ms/step - loss: 3.2349 - accuracy: 0.1273
# Epoch 14/20
# 2/2 [==============================] - 0s 21ms/step - loss: 3.2087 - accuracy: 0.1273
# Epoch 15/20
# 2/2 [==============================] - 0s 23ms/step - loss: 3.1915 - accuracy: 0.1273
# Epoch 16/20
# 2/2 [==============================] - 0s 26ms/step - loss: 3.1722 - accuracy: 0.1273
# Epoch 17/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.1465 - accuracy: 0.1273
# Epoch 18/20
# 2/2 [==============================] - 0s 22ms/step - loss: 3.1354 - accuracy: 0.1273
# Epoch 19/20
# 2/2 [==============================] - 0s 24ms/step - loss: 3.1117 - accuracy: 0.1273
# Epoch 20/20
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0947 - accuracy: 0.1273
# Training with 60 epochs...
# Epoch 1/60
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0677 - accuracy: 0.1273
# Epoch 2/60
# 2/2 [==============================] - 0s 24ms/step - loss: 3.0623 - accuracy: 0.1273
# Epoch 3/60
# 2/2 [==============================] - 0s 25ms/step - loss: 3.0354 - accuracy: 0.1273
# Epoch 4/60
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0181 - accuracy: 0.1273
# Epoch 5/60
# 2/2 [==============================] - 0s 22ms/step - loss: 3.0032 - accuracy: 0.1455
# Epoch 6/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9837 - accuracy: 0.1273
# Epoch 7/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9751 - accuracy: 0.1455
# Epoch 8/60
# 2/2 [==============================] - 0s 26ms/step - loss: 2.9599 - accuracy: 0.1455
# Epoch 9/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9439 - accuracy: 0.1455
# Epoch 10/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.9325 - accuracy: 0.1455
# Epoch 11/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9092 - accuracy: 0.1455
# Epoch 12/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8891 - accuracy: 0.1273
# Epoch 13/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8724 - accuracy: 0.1455
# Epoch 14/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8585 - accuracy: 0.1455
# Epoch 15/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8510 - accuracy: 0.1455
# Epoch 16/60
# 2/2 [==============================] - 0s 24ms/step - loss: 2.8328 - accuracy: 0.1636
# Epoch 17/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8200 - accuracy: 0.1455
# Epoch 18/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8116 - accuracy: 0.1455
# Epoch 19/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7872 - accuracy: 0.1455
# Epoch 20/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.7808 - accuracy: 0.1455
# Epoch 21/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.7629 - accuracy: 0.1636
# Epoch 22/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7541 - accuracy: 0.1636
# Epoch 23/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7360 - accuracy: 0.1636
# Epoch 24/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7303 - accuracy: 0.1636
# Epoch 25/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7169 - accuracy: 0.1818
# Epoch 26/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7006 - accuracy: 0.1818
# Epoch 27/60
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6922 - accuracy: 0.1455
# Epoch 28/60
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6752 - accuracy: 0.1455
# Epoch 29/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6698 - accuracy: 0.1636
# Epoch 30/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6582 - accuracy: 0.1636
# Epoch 31/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.6361 - accuracy: 0.2000
# Epoch 32/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6220 - accuracy: 0.1818
# Epoch 33/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6220 - accuracy: 0.2000
# Epoch 34/60
# 2/2 [==============================] - 0s 25ms/step - loss: 2.6087 - accuracy: 0.2182
# Epoch 35/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.5918 - accuracy: 0.2000
# Epoch 36/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.5785 - accuracy: 0.1818
# Epoch 37/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5791 - accuracy: 0.2364
# Epoch 38/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5559 - accuracy: 0.1818
# Epoch 39/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5604 - accuracy: 0.2364
# Epoch 40/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5453 - accuracy: 0.2000
# Epoch 41/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.5273 - accuracy: 0.2000
# Epoch 42/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5064 - accuracy: 0.2182
# Epoch 43/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4999 - accuracy: 0.2545
# Epoch 44/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4847 - accuracy: 0.2727
# Epoch 45/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4955 - accuracy: 0.2182
# Epoch 46/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4765 - accuracy: 0.2182
# Epoch 47/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4577 - accuracy: 0.2364
# Epoch 48/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.4487 - accuracy: 0.2182
# Epoch 49/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.4141 - accuracy: 0.2182
# Epoch 50/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4070 - accuracy: 0.2364
# Epoch 51/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4068 - accuracy: 0.2364
# Epoch 52/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3752 - accuracy: 0.2364
# Epoch 53/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.3551 - accuracy: 0.2727
# Epoch 54/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3628 - accuracy: 0.2545
# Epoch 55/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3599 - accuracy: 0.2182
# Epoch 56/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3004 - accuracy: 0.2364
# Epoch 57/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3006 - accuracy: 0.2545
# Epoch 58/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2873 - accuracy: 0.2182
# Epoch 59/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2494 - accuracy: 0.3273
# Epoch 60/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2492 - accuracy: 0.2545
# Training with 70 epochs...
# Epoch 1/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2278 - accuracy: 0.3273
# Epoch 2/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2187 - accuracy: 0.3273
# Epoch 3/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.1859 - accuracy: 0.2909
# Epoch 4/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.1742 - accuracy: 0.3455
# Epoch 5/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1564 - accuracy: 0.3273
# Epoch 6/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1261 - accuracy: 0.4182
# Epoch 7/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.1227 - accuracy: 0.3818
# Epoch 8/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0943 - accuracy: 0.3455
# Epoch 9/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0710 - accuracy: 0.3455
# Epoch 10/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0515 - accuracy: 0.3818
# Epoch 11/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0491 - accuracy: 0.3636
# Epoch 12/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0299 - accuracy: 0.4182
# Epoch 13/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0103 - accuracy: 0.3636
# Epoch 14/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9952 - accuracy: 0.3818
# Epoch 15/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.9555 - accuracy: 0.4000
# Epoch 16/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.9247 - accuracy: 0.4364
# Epoch 17/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.9228 - accuracy: 0.3636
# Epoch 18/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.9018 - accuracy: 0.3455
# Epoch 19/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.8511 - accuracy: 0.4000
# Epoch 20/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8758 - accuracy: 0.4182
# Epoch 21/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8518 - accuracy: 0.3818
# Epoch 22/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8169 - accuracy: 0.4545
# Epoch 23/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.7867 - accuracy: 0.4545
# Epoch 24/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.7693 - accuracy: 0.4364
# Epoch 25/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.7384 - accuracy: 0.4727
# Epoch 26/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.7162 - accuracy: 0.6000
# Epoch 27/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.7040 - accuracy: 0.5818
# Epoch 28/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.7028 - accuracy: 0.5091
# Epoch 29/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6736 - accuracy: 0.4727
# Epoch 30/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.6284 - accuracy: 0.5091
# Epoch 31/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6415 - accuracy: 0.5273
# Epoch 32/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6455 - accuracy: 0.5273
# Epoch 33/70
# 2/2 [==============================] - 0s 23ms/step - loss: 1.5888 - accuracy: 0.5455
# Epoch 34/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5604 - accuracy: 0.5273
# Epoch 35/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5445 - accuracy: 0.5636
# Epoch 36/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5040 - accuracy: 0.6000
# Epoch 37/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.5183 - accuracy: 0.6182
# Epoch 38/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5280 - accuracy: 0.6182
# Epoch 39/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5139 - accuracy: 0.5636
# Epoch 40/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5011 - accuracy: 0.6182
# Epoch 41/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4730 - accuracy: 0.5636
# Epoch 42/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5074 - accuracy: 0.6000
# Epoch 43/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4281 - accuracy: 0.5818
# Epoch 44/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5076 - accuracy: 0.5455
# Epoch 45/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4483 - accuracy: 0.5636
# Epoch 46/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4564 - accuracy: 0.6364
# Epoch 47/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3660 - accuracy: 0.6545
# Epoch 48/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.3610 - accuracy: 0.6727
# Epoch 49/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3220 - accuracy: 0.6545
# Epoch 50/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3519 - accuracy: 0.5818
# Epoch 51/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3138 - accuracy: 0.6545
# Epoch 52/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2995 - accuracy: 0.6727
# Epoch 53/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2834 - accuracy: 0.6727
# Epoch 54/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2513 - accuracy: 0.7091
# Epoch 55/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2228 - accuracy: 0.6545
# Epoch 56/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2397 - accuracy: 0.7091
# Epoch 57/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2028 - accuracy: 0.7636
# Epoch 58/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1733 - accuracy: 0.7091
# Epoch 59/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1765 - accuracy: 0.6909
# Epoch 60/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1534 - accuracy: 0.7273
# Epoch 61/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1391 - accuracy: 0.8000
# Epoch 62/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1427 - accuracy: 0.7818
# Epoch 63/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1364 - accuracy: 0.7273
# Epoch 64/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.0865 - accuracy: 0.7636
# Epoch 65/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.0980 - accuracy: 0.7818
# Epoch 66/70
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1176 - accuracy: 0.6364
# Epoch 67/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1558 - accuracy: 0.7818
# Epoch 68/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1584 - accuracy: 0.6364
# Epoch 69/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1114 - accuracy: 0.7455
# Epoch 70/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.0520 - accuracy: 0.7818
# Generated text: Once upon a time there there was a little named red riding hood she loved visit her who lived lived in the woods one one day her asked her to her basket of to her basket goodies her goodies her grandmother way the through the woods she met a a big wolf wolf who
